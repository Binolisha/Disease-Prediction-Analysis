# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
parkinsons=pd.read_excel("parkinsons.xlsx")

# %%
parkinsons
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0    phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1    phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2    phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3    phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4    phon_R01_S01_5      116.014       141.781       110.655         0.01284
# ..              ...          ...           ...           ...             ...
# 190  phon_R01_S50_2      174.188       230.978        94.261         0.00459
# 191  phon_R01_S50_3      209.516       253.017        89.488         0.00564
# 192  phon_R01_S50_4      174.688       240.005        74.287         0.01360
# 193  phon_R01_S50_5      198.764       396.961        74.904         0.00740
# 194  phon_R01_S50_6      214.289       260.277        77.973         0.00567
#
# ...

# %%
parkinsons.shape #195 rows and 24 columns
# Out:
# (195, 24)

# %%
parkinsons.columns
# Out:
# Index(['name', 'MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
#        'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
#        'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'status', 'RPDE', 'DFA',
#        'spread1', 'spread2', 'D2', 'PPE'],
#       dtype='object')

# %%
parkinsons["name"].value_counts()  #195 types of parkinson
# Out:
# name
# phon_R01_S01_1    1
# phon_R01_S35_1    1
# phon_R01_S31_3    1
# phon_R01_S31_4    1
# phon_R01_S31_5    1
#                  ..
# phon_R01_S18_2    1
# phon_R01_S18_3    1
# phon_R01_S18_4    1
# phon_R01_S18_5    1
# phon_R01_S50_6    1
# Name: count, Length: 195, dtype: int64

# %%
parkinsons["status"].value_counts()
# Out:
# status
# 1    147
# 0     48
# Name: count, dtype: int64

# %%
parkinsons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
parkinsons.isnull().sum()*100 #no null values
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
parkinsons.duplicated().sum() #no duplicates
# Out:
# 0

# %%
parkinsons.columns
# Out:
# Index(['name', 'MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
#        'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
#        'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'status', 'RPDE', 'DFA',
#        'spread1', 'spread2', 'D2', 'PPE'],
#       dtype='object')

# %%
parkinsons["name"].unique()
# Out:
# array(['phon_R01_S01_1', 'phon_R01_S01_2', 'phon_R01_S01_3',
#        'phon_R01_S01_4', 'phon_R01_S01_5', 'phon_R01_S01_6',
#        'phon_R01_S02_1', 'phon_R01_S02_2', 'phon_R01_S02_3',
#        'phon_R01_S02_4', 'phon_R01_S02_5', 'phon_R01_S02_6',
#        'phon_R01_S04_1', 'phon_R01_S04_2', 'phon_R01_S04_3',
#        'phon_R01_S04_4', 'phon_R01_S04_5', 'phon_R01_S04_6',
#        'phon_R01_S05_1', 'phon_R01_S05_2', 'phon_R01_S05_3',
#        'phon_R01_S05_4', 'phon_R01_S05_5', 'phon_R01_S05_6',
#        'phon_R01_S06_1', 'phon_R01_S06_2', 'phon_R01_S06_3',
#        'phon_R01_S06_4', 'phon_R01_S06_5', 'phon_R01_S06_6',
#        'phon_R01_S07_1', 'phon_R01_S07_2', 'phon_R01_S07_3',
#        'phon_R01_S07_4', 'phon_R01_S07_5', 'phon_R01_S07_6',
#        'phon_R01_S08_1', 'phon_R01_S08_2', 'phon_R01_S08_3',
#        'phon_R01_S08_4', 'phon_R01_S08_5', 'phon_R01_S08_6',
#        'phon_R01_S10_1', 'phon_R01_S10_2', 'phon_R01_S10_3',
# ...

# %%
#Univariant analysis
plt.figure(figsize=(12,8))
sns.boxplot(data=parkinsons)
plt.xticks(rotation=45)
plt.title("Box plot")
plt.show() #outliers in second and third column

# %%
sns.distplot(parkinsons["MDVP:Fo(Hz)"])  #right skew
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_22116\3597430522.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(parkinsons["MDVP:Fo(Hz)"])  #right skew
# <Axes: xlabel='MDVP:Fo(Hz)', ylabel='Density'>

# %%
parkinsons["MDVP:Fo(Hz)"].skew()
# Out:
# 0.5917374636540784

# %%
#outlier treatment
q1 = parkinsons["MDVP:Fo(Hz)"].quantile(0.25)
q3 = parkinsons["MDVP:Fo(Hz)"].quantile(0.75)
iqr = q3 - q1

ll = q1 - 1.5*iqr
ul = q3 + 1.5*iqr

parkinsons= parkinsons[(parkinsons["MDVP:Fo(Hz)"] > ll) & (parkinsons["MDVP:Fo(Hz)"] < ul)]

# %%
parkinsons["MDVP:Fo(Hz)"].skew()
# Out:
# 0.5917374636540784

# %%
parkinsons["MDVP:Fo(Hz)"]
# Out:
# 0      119.992
# 1      122.400
# 2      116.682
# 3      116.676
# 4      116.014
#         ...
# 190    174.188
# 191    209.516
# 192    174.688
# 193    198.764
# 194    214.289
# Name: MDVP:Fo(Hz), Length: 195, dtype: float64

# %%
parkinsons["MDVP:Fo(Hz)"] = np.log1p(parkinsons["MDVP:Fo(Hz)"])

# %%
parkinsons["MDVP:Fo(Hz)"].skew()
# Out:
# 0.2166069249459361

# %%
parkinsons["MDVP:Fo(Hz)"]
# Out:
# 0      4.795724
# 1      4.815431
# 2      4.767986
# 3      4.767935
# 4      4.762294
#          ...
# 190    5.165860
# 191    5.349562
# 192    5.168710
# 193    5.297137
# 194    5.371981
# Name: MDVP:Fo(Hz), Length: 195, dtype: float64

# %%
from scipy import stats
parkinsons["MDVP:Fo(Hz)"], _ = stats.boxcox(parkinsons["MDVP:Fo(Hz)"])

# %%
parkinsons["MDVP:Fo(Hz)"].skew()
# Out:
# 0.02782067529969162

# %%
parkinsons["MDVP:Fo(Hz)"]
# Out:
# 0      0.591579
# 1      0.591945
# 2      0.591057
# 3      0.591056
# 4      0.590949
#          ...
# 190    0.597872
# 191    0.600590
# 192    0.597916
# 193    0.599838
# 194    0.600905
# Name: MDVP:Fo(Hz), Length: 195, dtype: float64

# %%
sns.distplot(parkinsons["MDVP:Fo(Hz)"])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_22116\1771200609.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(parkinsons["MDVP:Fo(Hz)"])
# <Axes: xlabel='MDVP:Fo(Hz)', ylabel='Density'>

# %%
sns.distplot(parkinsons["MDVP:Fhi(Hz)"])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_22116\3686331063.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(parkinsons["MDVP:Fhi(Hz)"])
# <Axes: xlabel='MDVP:Fhi(Hz)', ylabel='Density'>

# %%
parkinsons["MDVP:Fhi(Hz)"].skew()
# Out:
# 2.542145997588398

# %%
#outlier treatment
q1 = parkinsons["MDVP:Fhi(Hz)"].quantile(0.25)
q3 = parkinsons["MDVP:Fhi(Hz)"].quantile(0.75)
iqr = q3 - q1

ll = q1 - 1.5*iqr
ul = q3 + 1.5*iqr

parkinsons= parkinsons[(parkinsons["MDVP:Fhi(Hz)"] > ll) & (parkinsons["MDVP:Fhi(Hz)"] < ul)]

# %%
parkinsons["MDVP:Fhi(Hz)"].skew()
# Out:
# 0.45383393634180585

# %%
parkinsons["MDVP:Fhi(Hz)"] = np.log1p(parkinsons["MDVP:Fhi(Hz)"])

# %%
parkinsons["MDVP:Fhi(Hz)"].skew()
# Out:
# 0.06066476745314866

# %%
sns.distplot(parkinsons["MDVP:Flo(Hz)"])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_22116\1676970722.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(parkinsons["MDVP:Flo(Hz)"])
# <Axes: xlabel='MDVP:Flo(Hz)', ylabel='Density'>

# %%
parkinsons["MDVP:Flo(Hz)"].skew()
# Out:
# 1.186529235540597

# %%
#outlier treatment
q1 = parkinsons["MDVP:Flo(Hz)"].quantile(0.25)
q3 = parkinsons["MDVP:Flo(Hz)"].quantile(0.75)
iqr = q3 - q1

ll = q1 - 1.5*iqr
ul = q3 + 1.5*iqr

parkinsosns = parkinsons[(parkinsons["MDVP:Flo(Hz)"] > ll) & (parkinsons["MDVP:Flo(Hz)"] < ul)]

# %%
parkinsons["MDVP:Flo(Hz)"].skew()
# Out:
# 1.186529235540597

# %%
parkinsons["MDVP:Flo(Hz)"] = np.log1p(parkinsons["MDVP:Flo(Hz)"])

# %%
parkinsons["MDVP:Flo(Hz)"].skew()
# Out:
# 0.6357779096799803

# %%
parkinsons["MDVP:Flo(Hz)"], _ = stats.boxcox(parkinsons["MDVP:Flo(Hz)"])

# %%
parkinsons["MDVP:Flo(Hz)"].skew()
# Out:
# 0.0756362638125503

# %%
parkinsons.shape
# Out:
# (184, 24)

# %%
#eda
sns.histplot(parkinsons["status"])
# Out:
# <Axes: xlabel='status', ylabel='Count'>

# %%
plt.figure(figsize=(12,6))
sns.violinplot(data=parkinsons,x=parkinsons["status"], y=parkinsons["MDVP:Fo(Hz)"])
plt.title("MDVP:Fo(Hz) vs. Status")
plt.show()
# if the hz is less than 0.600 the status is 1(value less than 0.600 has high chance of disease)

# %%
plt.figure(figsize=(12,6))
sns.violinplot(data=parkinsons,x=parkinsons["status"], y=parkinsons['MDVP:Fhi(Hz)'])
plt.title("MDVP:Fhi(Hz) vs. Status")
plt.show()
#less than 200 has the status 1(0-100 ranging have haigh chance of disease)

# %%
plt.figure(figsize=(12,6))
sns.violinplot(data=parkinsons,x=parkinsons["status"], y=parkinsons['MDVP:Flo(Hz)'])
plt.title("MDVP:Flo(Hz) vs. Status")
plt.show()
#less than 225 has status 1(less mdvp flo has high chance of disease)

# %%
plt.figure(figsize=(12,6))
sns.violinplot(data=parkinsons,x=parkinsons["status"], y=parkinsons['MDVP:Jitter(%)'])
plt.title("MDVP:Jitter(%) vs. Status")
plt.show()
#higher jitter status 1(high value shows the chance of disease)

# %%
plt.figure(figsize=(12,6))
sns.violinplot(data=parkinsons,x=parkinsons["status"], y=parkinsons['MDVP:Jitter(Abs)'])
plt.title("MDVP:Jitter(Abs) vs. Status")
plt.show()
#low value (0.00005 =-) have less chance while high value have high chance

# %%
plt.figure(figsize=(12,6))
sns.violinplot(data=parkinsons,x=parkinsons["status"], y=parkinsons['MDVP:RAP'])
plt.title("MDVP:RAP vs. Status")
plt.show()
#low value less than 0.0025 has less chance while high value has the high chance of disease

# %%
plt.figure(figsize=(12,6))
sns.violinplot(data=parkinsons,x=parkinsons["status"], y=parkinsons['MDVP:PPQ'])
plt.title("MDVP:PPQ vs. Status")
plt.show()
#lower than 0.0025 has less chance of disease

# %%
plt.figure(figsize=(12,6))
sns.violinplot(data=parkinsons,x=parkinsons["status"], y=parkinsons['Jitter:DDP'])
plt.title("Jitter:DDP vs. Status")
plt.show()
#lower than 0.0025 has less chance of disease

# %%
plt.figure(figsize=(12,6))
sns.violinplot(data=parkinsons,x=parkinsons["status"], y=parkinsons['MDVP:Shimmer'])
plt.title("MDVP:Shimmer vs. Status")
plt.show()
#lower than 0.0025 has less chance of disease

# %%
plt.figure(figsize=(12,6))
sns.violinplot(data=parkinsons,x=parkinsons["status"], y=parkinsons['MDVP:Shimmer(dB)'])
plt.title("MDVP:Shimmer(dB) vs. Status")
plt.show()
#lower than 0.0025 has less chance of disease

# %%
plt.figure(figsize=(12,6))
sns.violinplot(data=parkinsons,x=parkinsons["status"], y=parkinsons['Shimmer:APQ3'])
plt.title("Shimmer:APQ3 vs. Status")
plt.show()
#lower than 0.02 has less chance of disease

# %%
plt.figure(figsize=(12,6))
sns.violinplot(data=parkinsons,x=parkinsons["status"], y=parkinsons['Shimmer:APQ5'])
plt.title("Shimmer:APQ5 vs. Status")
plt.show()
#lower than 0.02 has less chance of disease

# %%
plt.figure(figsize=(12,6))
sns.violinplot(data=parkinsons,x=parkinsons["status"], y=parkinsons['MDVP:APQ'])
plt.title("MDVP:APQ vs. Status")
plt.show()
#lower than 0.02 has less chance of disease

# %%
plt.figure(figsize=(12,6))
sns.violinplot(data=parkinsons,x=parkinsons["status"], y=parkinsons['Shimmer:DDA'])
plt.title("Shimmer:DDA vs. Status")
plt.show()
#lower than 0.080 has less chance of disease(more commonly people are in the range of 0.25 to 0.50)

# %%
plt.figure(figsize=(12,6))
sns.violinplot(data=parkinsons,x=parkinsons["status"], y=parkinsons['NHR'])
plt.title("NHR vs. Status")
plt.show()
#lower than 0.01 has less chance of disease(more commonly people are in the value of 0.01)

# %%
plt.figure(figsize=(12,6))
sns.violinplot(data=parkinsons,x=parkinsons["status"], y=parkinsons['HNR'])
plt.title("HNR vs. Status")
plt.show()
# individuals with Parkinson's tend to have lower Harmonic-to-Noise Ratios (HNR) compared to those without

# %%
plt.figure(figsize=(12,6))
sns.violinplot(data=parkinsons,x=parkinsons["status"], y=parkinsons['RPDE'])
plt.title("RPDE vs. Status")
plt.show()
#higher RPDE values in Parkinson's could be related

# %%
plt.figure(figsize=(12,6))
sns.violinplot(data=parkinsons,x=parkinsons["status"], y=parkinsons['DFA'])
plt.title("DFA vs. Status")
plt.show()
# individuals with Parkinson's tend to have higher Detrended Fluctuation Analysis (DFA) values compared to those without

# %%
plt.figure(figsize=(12,6))
sns.violinplot(data=parkinsons,x=parkinsons["status"], y=parkinsons['spread1'])
plt.title("spread1 vs. Status")
plt.show()
#individuals with Parkinson's tend to have higher spread1 values compared to those without(lasts at -9 to -5.5 for no disease)

# %%
plt.figure(figsize=(12,6))
sns.violinplot(data=parkinsons,x=parkinsons["status"], y=parkinsons['spread2'])
plt.title("spread2 vs. Status")
plt.show()
# individuals with Parkinson's tend to have higher spread2 values compared to those without.(wide range at 0.19 and ends till 0.35)

# %%
plt.figure(figsize=(12,6))
sns.violinplot(data=parkinsons,x=parkinsons["status"], y=parkinsons['D2'])
plt.title("D2 vs. Status")
plt.show()
#individuals with Parkinson's tend to have higher D2 values compared to those without(wide range in 2.1 till 3.3 for 0 status)

# %%
plt.figure(figsize=(12,6))
sns.violinplot(data=parkinsons,x=parkinsons["status"], y=parkinsons['PPE'])
plt.title("PPE vs. Status")
plt.show()
#ndividuals with Parkinson's tend to have higher PPE values compared to those without(0-0.3 FOR no disease)

# %%
heat_column=parkinsons.drop(columns=["name"],errors="ignore")
corr_matrix =heat_column.corr()
plt.figure(figsize=(12,8))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
parkinsons.drop(columns=["name"],inplace=True)

# %%
parkinsons
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0       0.591579      5.064505      0.266379         0.00784
# 1       0.591945      5.008299      0.266701         0.00968
# 2       0.591057      4.883642      0.266688         0.01050
# 3       0.591056      4.933545      0.266687         0.00997
# 4       0.590949      4.961312      0.266683         0.01284
# ..           ...           ...           ...             ...
# 189     0.600055      5.574839      0.266418         0.00694
# 190     0.597872      5.446643      0.266572         0.00459
# 191     0.600590      5.537401      0.266532         0.00564
# 192     0.597916      5.484818      0.266370         0.01360
# 194     0.600905      5.565581      0.266415         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0             0.00007   0.00370   0.00554     0.01109       0.04374
# 1             0.00008   0.00465   0.00696     0.01394       0.06134
# ...

# %%
parkinsons["status"].value_counts()
# Out:
# status
# 1    139
# 0     45
# Name: count, dtype: int64

# %%
x=parkinsons.drop("status",axis=1)
y=parkinsons["status"]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = scaler.fit_transform(x)

# %%
x
# Out:
# array([[-0.80294873, -0.33551087, -1.34087276, ...,  0.50843461,
#         -0.18753688,  0.88234343],
#        [-0.71915489, -0.54648604,  0.23884989, ...,  1.34157115,
#          0.29766672,  1.81961696],
#        [-0.92238569, -1.01440364,  0.17706176, ...,  1.04721022,
#         -0.08072368,  1.41757771],
#        ...,
#        [ 1.25901916,  1.43957653, -0.58879774, ..., -1.14533682,
#          1.07607603, -0.40899013],
#        [ 0.64714405,  1.24219652, -1.38548197, ..., -0.79391687,
#          0.80250738, -0.82360148],
#        [ 1.33124168,  1.54535415, -1.16300663, ..., -0.40555864,
#          0.47724227, -0.63573403]])

# %%
x.shape
# Out:
# (184, 22)

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(x,y , random_state=45,test_size=0.30)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((128, 22), (56, 22), (128,), (56,))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_score, recall_score, f1_score
LR = LogisticRegression(max_iter=10000, random_state=0)
LR.fit(X_train, y_train)
y_predict=LR.predict(X_test)
precision = precision_score(y_test, y_predict, average='binary')
recall = recall_score(y_test, y_predict, average='binary')
f1 = f1_score(y_test, y_predict, average='binary')
print(f"precision:{precision},\nrecall:{recall},\nf1score:{f1}")
# Out:
# precision:0.9069767441860465,
# recall:0.9512195121951219,
# f1score:0.9285714285714286

# %%
from sklearn.svm import SVC
svc = SVC(kernel='rbf')  
svc.fit(X_train, y_train) 
y_predict = svc.predict(X_test) 
precision = precision_score(y_test, y_predict, average='binary')
recall = recall_score(y_test, y_predict, average='binary')
f1 = f1_score(y_test, y_predict, average='binary')
print(f"precision:{precision},\nrecall:{recall},\nf1score:{f1}")
# Out:
# precision:0.8913043478260869,
# recall:1.0,
# f1score:0.9425287356321839

# %%
from sklearn.tree import DecisionTreeClassifier

# Initialize and train the classifier
dtc = DecisionTreeClassifier(random_state=0,max_depth=2)
dtc.fit(X_train, y_train)

# Predict and evaluate
y_predict = dtc.predict(X_test)
precision = precision_score(y_test, y_predict, average='binary')
recall = recall_score(y_test, y_predict, average='binary')
f1 = f1_score(y_test, y_predict, average='binary')

print(f"Decision Tree Classifier\nPrecision: {precision}\nRecall: {recall}\nF1 Score: {f1}")

# %%
from sklearn.ensemble import RandomForestClassifier

# Initialize and train the classifier
rfc = RandomForestClassifier(random_state=0,max_depth=2)
rfc.fit(X_train, y_train)

# Predict and evaluate
y_predict = rfc.predict(X_test)
precision = precision_score(y_test, y_predict, average='binary')
recall = recall_score(y_test, y_predict, average='binary')
f1 = f1_score(y_test, y_predict, average='binary')

print(f"Random Forest Classifier\nPrecision: {precision}\nRecall: {recall}\nF1 Score: {f1}")

# %%
from sklearn.neighbors import KNeighborsClassifier

# Initialize and train the classifier
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)

# Predict and evaluate
y_predict = knn.predict(X_test)
precision = precision_score(y_test, y_predict, average='binary')
recall = recall_score(y_test, y_predict, average='binary')
f1 = f1_score(y_test, y_predict, average='binary')

print(f"K-Nearest Neighbors\nPrecision: {precision}\nRecall: {recall}\nF1 Score: {f1}")

# %%
from sklearn.naive_bayes import GaussianNB

# Initialize and train the classifier
nb = GaussianNB()
nb.fit(X_train, y_train)

# Predict and evaluate
y_predict = nb.predict(X_test)
precision = precision_score(y_test, y_predict, average='binary')
recall = recall_score(y_test, y_predict, average='binary')
f1 = f1_score(y_test, y_predict, average='binary')

print(f"Naive Bayes Classifier\nPrecision: {precision}\nRecall: {recall}\nF1 Score: {f1}")
