# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
liver=pd.read_excel("indian_liver_patient.xlsx")
liver
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65  Female              0.7               0.1                   187
# 1     62    Male             10.9               5.5                   699
# 2     62    Male              7.3               4.1                   490
# 3     58    Male              1.0               0.4                   182
# 4     72    Male              3.9               2.0                   195
# ..   ...     ...              ...               ...                   ...
# 578   60    Male              0.5               0.1                   500
# 579   40    Male              0.6               0.1                    98
# 580   52    Male              0.8               0.2                   245
# 581   31    Male              1.3               0.5                   184
# 582   38    Male              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# ...

# %%
liver.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    4
# Dataset                       0
# dtype: int64

# %%
liver["Albumin_and_Globulin_Ratio"]=liver["Albumin_and_Globulin_Ratio"].fillna(liver["Albumin_and_Globulin_Ratio"].median())

# %%
liver["Albumin_and_Globulin_Ratio"].unique()
# Out:
# array([0.9 , 0.74, 0.89, 1.  , 0.4 , 1.3 , 1.1 , 1.2 , 0.8 , 0.6 , 0.87,
#        0.7 , 0.92, 0.55, 0.5 , 1.85, 0.95, 1.4 , 1.18, 0.61, 1.34, 1.39,
#        1.6 , 1.58, 1.25, 0.78, 0.76, 1.55, 0.71, 0.62, 0.67, 0.75, 1.16,
#        1.5 , 1.66, 0.96, 1.38, 0.52, 0.47, 0.93, 0.48, 0.58, 0.69, 1.27,
#        1.12, 1.06, 0.53, 1.03, 0.68, 1.9 , 1.7 , 1.8 , 0.3 , 0.97, 0.35,
#        1.51, 0.64, 0.45, 1.36, 0.88, 1.09, 1.11, 1.72, 2.8 , 0.46, 0.39,
#        1.02, 2.5 , 0.37])

# %%
liver.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    0
# Dataset                       0
# dtype: int64

# %%
liver.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         583 non-null    int64
#  1   Gender                      583 non-null    object
#  2   Total_Bilirubin             583 non-null    float64
#  3   Direct_Bilirubin            583 non-null    float64
#  4   Alkaline_Phosphotase        583 non-null    int64
#  5   Alamine_Aminotransferase    583 non-null    int64
#  6   Aspartate_Aminotransferase  583 non-null    int64
#  7   Total_Protiens              583 non-null    float64
#  8   Albumin                     583 non-null    float64
#  9   Albumin_and_Globulin_Ratio  583 non-null    float64
#  10  Dataset                     583 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.2+ KB

# %%
sns.boxplot(liver)
plt.xticks(rotation=45)
plt.show()

# %%
sns.countplot(liver["Gender"])
# Out:
# <Axes: xlabel='count', ylabel='Gender'>

# %%
numeric_columns = [
    'Age', 'Total_Bilirubin', 'Direct_Bilirubin', 'Alkaline_Phosphotase', 
    'Alamine_Aminotransferase', 'Aspartate_Aminotransferase', 'Total_Protiens', 
    'Albumin', 'Albumin_and_Globulin_Ratio'
]

# Set up the plot
plt.figure(figsize=(12, 10))

# Loop through each numeric column and create a boxplot against the 'Dataset' column
for i, column in enumerate(numeric_columns, 1):
    plt.subplot(3, 3, i)  # Set up a 3x3 grid of plots
    sns.boxplot(x='Dataset', y=column, data=liver)
    plt.title(f'Boxplot of {column} vs Dataset')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame
# List of numeric columns
numeric_columns = [
    'Age', 'Total_Bilirubin', 'Direct_Bilirubin', 'Alkaline_Phosphotase', 
    'Alamine_Aminotransferase', 'Aspartate_Aminotransferase', 'Total_Protiens', 
    'Albumin', 'Albumin_and_Globulin_Ratio'
]

# Set up the plot
plt.figure(figsize=(12, 10))

# Loop through each numeric column and create a violin plot
for i, column in enumerate(numeric_columns, 1):
    plt.subplot(3, 3, i)  # Set up a 3x3 grid of plots
    sns.violinplot(x='Dataset', y=column, data=liver)
    plt.title(f'Violin Plot of {column} vs Dataset')

plt.tight_layout()
plt.show()

# %%
gender_count = liver.groupby(['Dataset', 'Gender']).size().reset_index(name='Count')
plt.figure(figsize=(8, 6))
sns.barplot(x='Dataset', y='Count', hue='Gender', data=gender_count)

# Set the title and labels
plt.title('Gender Count by Dataset')
plt.xlabel('Dataset')
plt.ylabel('Count')

# Display the plot
plt.show()

# %%
liver["Total_Bilirubin"].skew(),liver["Direct_Bilirubin"].skew(),liver["Alkaline_Phosphotase"].skew(),liver["Alamine_Aminotransferase"].skew(),liver["Aspartate_Aminotransferase"].skew()
# Out:
# (4.90747399372197,
#  3.21240286208773,
#  3.7651063973073766,
#  6.549191929444977,
#  10.54617721691247)

# %%
Q1 = liver['Total_Bilirubin'].quantile(0.25)  
Q3 = liver["Total_Bilirubin"].quantile(0.75)  
IQR = Q3 - Q1 
lower_bound = Q1 - 1.5 * IQR  # Lower boundary for outliers
upper_bound = Q3 + 1.5 * IQR  # Upper boundary for outliers
outliers = liver[(liver["Total_Bilirubin"] < lower_bound) | (liver["Total_Bilirubin"] > upper_bound)]

# %%
Q1 = liver['Direct_Bilirubin'].quantile(0.25)  
Q3 = liver["Direct_Bilirubin"].quantile(0.75)  
IQR = Q3 - Q1 
lower_bound = Q1 - 1.5 * IQR  # Lower boundary for outliers
upper_bound = Q3 + 1.5 * IQR  # Upper boundary for outliers
outliers = liver[(liver["Direct_Bilirubin"] < lower_bound) | (liver["Direct_Bilirubin"] > upper_bound)]

# %%
Q1 = liver['Alkaline_Phosphotase'].quantile(0.25)  
Q3 = liver["Alkaline_Phosphotase"].quantile(0.75)  
IQR = Q3 - Q1 
lower_bound = Q1 - 1.5 * IQR  # Lower boundary for outliers
upper_bound = Q3 + 1.5 * IQR  # Upper boundary for outliers
outliers = liver[(liver["Alkaline_Phosphotase"] < lower_bound) | (liver["Alkaline_Phosphotase"] > upper_bound)]

# %%
Q1 = liver['Alamine_Aminotransferase'].quantile(0.25)  
Q3 = liver["Alamine_Aminotransferase"].quantile(0.75)  
IQR = Q3 - Q1 
lower_bound = Q1 - 1.5 * IQR  # Lower boundary for outliers
upper_bound = Q3 + 1.5 * IQR  # Upper boundary for outliers
outliers = liver[(liver["Alamine_Aminotransferase"] < lower_bound) | (liver["Alamine_Aminotransferase"] > upper_bound)]

# %%
Q1 = liver['Aspartate_Aminotransferase'].quantile(0.25)  
Q3 = liver["Aspartate_Aminotransferase"].quantile(0.75)  
IQR = Q3 - Q1 
lower_bound = Q1 - 1.5 * IQR  # Lower boundary for outliers
upper_bound = Q3 + 1.5 * IQR  # Upper boundary for outliers
outliers = liver[(liver["Aspartate_Aminotransferase"] < lower_bound) | (liver["Aspartate_Aminotransferase"] > upper_bound)]

# %%
liver["Total_Bilirubin"].skew(),liver["Direct_Bilirubin"].skew(),liver["Alkaline_Phosphotase"].skew(),liver["Alamine_Aminotransferase"].skew(),liver["Aspartate_Aminotransferase"].skew()
# Out:
# (4.90747399372197,
#  3.21240286208773,
#  3.7651063973073766,
#  6.549191929444977,
#  10.54617721691247)

# %%
numeric_columns = [
    'Total_Bilirubin', 'Direct_Bilirubin', 'Alkaline_Phosphotase', 
    'Alamine_Aminotransferase', 'Aspartate_Aminotransferase'
]

# %%
from scipy.stats import zscore
numeric_columns = [
    'Total_Bilirubin', 'Direct_Bilirubin', 'Alkaline_Phosphotase', 
    'Alamine_Aminotransferase', 'Aspartate_Aminotransferase'
]
# Compute Z-scores for all numeric columns
z_scores = liver[numeric_columns].apply(zscore)

# Set threshold (e.g., 3 standard deviations from mean)
threshold = 3

# Filter out outliers
liver = liver[(z_scores.abs() < threshold).all(axis=1)]

# %%
import numpy as np

for column in numeric_columns:
    liver[column] = np.log1p(liver[column])  # Log transformation
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_32508\293402242.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liver[column] = np.log1p(liver[column])  # Log transformation

# %%
from sklearn.preprocessing import PowerTransformer

pt = PowerTransformer(method='yeo-johnson')
liver[numeric_columns] = pt.fit_transform(liver[numeric_columns])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_32508\3175461095.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liver[numeric_columns] = pt.fit_transform(liver[numeric_columns])

# %%
sns.boxplot(liver)
# Out:
# <Axes: >

# %%
liver["Total_Bilirubin"].skew(),liver["Direct_Bilirubin"].skew(),liver["Alkaline_Phosphotase"].skew(),liver["Alamine_Aminotransferase"].skew(),liver["Aspartate_Aminotransferase"].skew()
# Out:
# (-0.04034191024040721,
#  0.0221678877186775,
#  -0.13961872340772716,
#  0.010229567454642393,
#  0.040650029576561005)

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Assuming df is your DataFrame
label_encoder = LabelEncoder()

# Encode the 'Gender' column
liver['Gender'] = label_encoder.fit_transform(liver['Gender'])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_32508\409851836.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liver['Gender'] = label_encoder.fit_transform(liver['Gender'])

# %%
x=liver.drop("Dataset",axis=1)
y=liver["Dataset"]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
x = scaler.fit_transform(x)

# %%
x
# Out:
# array([[0.70930233, 0.        , 0.52420342, ..., 0.52173913, 0.24      ,
#         0.        ],
#        [0.6744186 , 1.        , 0.98059923, ..., 0.5       , 0.176     ,
#         1.        ],
#        [0.6744186 , 1.        , 0.96242827, ..., 0.52173913, 0.236     ,
#         1.        ],
#        ...,
#        [0.55813953, 1.        , 0.59335487, ..., 0.5       , 0.28      ,
#         1.        ],
#        [0.31395349, 1.        , 0.75919506, ..., 0.54347826, 0.28      ,
#         1.        ],
#        [0.39534884, 1.        , 0.68282527, ..., 0.76086957, 0.48      ,
#         1.        ]])

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(x,y , random_state=45,test_size=0.30)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((378, 11), (163, 11), (378,), (163,))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_score, recall_score, f1_score
LR = LogisticRegression(max_iter=10000, random_state=0)
LR.fit(X_train, y_train)
y_predict=LR.predict(X_test)
precision = precision_score(y_test, y_predict, average='binary')
recall = recall_score(y_test, y_predict, average='binary')
f1 = f1_score(y_test, y_predict, average='binary')
print(f"precision:{precision},\nrecall:{recall},\nf1score:{f1}")
# Out:
# precision:0.6466666666666666,
# recall:0.9238095238095239,
# f1score:0.7607843137254902

# %%
from sklearn.svm import SVC
svc = SVC(kernel='rbf')  
svc.fit(X_train, y_train) 
y_predict = svc.predict(X_test) 
precision = precision_score(y_test, y_predict, average='binary')
recall = recall_score(y_test, y_predict, average='binary')
f1 = f1_score(y_test, y_predict, average='binary')
print(f"precision:{precision},\nrecall:{recall},\nf1score:{f1}")
# Out:
# precision:0.6441717791411042,
# recall:1.0,
# f1score:0.7835820895522388

# %%
from sklearn.tree import DecisionTreeClassifier

# Initialize and train the classifier
dtc = DecisionTreeClassifier(random_state=0,max_depth=2)
dtc.fit(X_train, y_train)

# Predict and evaluate
y_predict = dtc.predict(X_test)
precision = precision_score(y_test, y_predict, average='binary')
recall = recall_score(y_test, y_predict, average='binary')
f1 = f1_score(y_test, y_predict, average='binary')

print(f"Decision Tree Classifier\nPrecision: {precision}\nRecall: {recall}\nF1 Score: {f1}")
# Out:
# Decision Tree Classifier
# Precision: 0.6441717791411042
# Recall: 1.0
# F1 Score: 0.7835820895522388

# %%
from sklearn.ensemble import RandomForestClassifier

# Initialize and train the classifier
rfc = RandomForestClassifier(random_state=0,max_depth=2)
rfc.fit(X_train, y_train)

# Predict and evaluate
y_predict = rfc.predict(X_test)
precision = precision_score(y_test, y_predict, average='binary')
recall = recall_score(y_test, y_predict, average='binary')
f1 = f1_score(y_test, y_predict, average='binary')

print(f"Random Forest Classifier\nPrecision: {precision}\nRecall: {recall}\nF1 Score: {f1}")
# Out:
# Random Forest Classifier
# Precision: 0.6441717791411042
# Recall: 1.0
# F1 Score: 0.7835820895522388

# %%
from sklearn.neighbors import KNeighborsClassifier

# Initialize and train the classifier
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)

# Predict and evaluate
y_predict = knn.predict(X_test)
precision = precision_score(y_test, y_predict, average='binary')
recall = recall_score(y_test, y_predict, average='binary')
f1 = f1_score(y_test, y_predict, average='binary')

print(f"K-Nearest Neighbors\nPrecision: {precision}\nRecall: {recall}\nF1 Score: {f1}")
# Out:
# K-Nearest Neighbors
# Precision: 0.703125
# Recall: 0.8571428571428571
# F1 Score: 0.7725321888412017

# %%
from sklearn.naive_bayes import GaussianNB

# Initialize and train the classifier
nb = GaussianNB()
nb.fit(X_train, y_train)

# Predict and evaluate
y_predict = nb.predict(X_test)
precision = precision_score(y_test, y_predict, average='binary')
recall = recall_score(y_test, y_predict, average='binary')
f1 = f1_score(y_test, y_predict, average='binary')

print(f"Naive Bayes Classifier\nPrecision: {precision}\nRecall: {recall}\nF1 Score: {f1}")
# Out:
# Naive Bayes Classifier
# Precision: 0.7582417582417582
# Recall: 0.6571428571428571
# F1 Score: 0.7040816326530612
